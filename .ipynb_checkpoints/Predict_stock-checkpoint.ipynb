# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %%
# claw data
def claw_DataStock_Gcafe(Name, Page):
    header= {
            'Cookie': 'favorite_stocks_state=1; __UF=-1; _uidcms=1658202174129752373; __R=2; __tb=0; _gid=GA1.2.1136744825.1661092261; __RC=31; cafef.IsMobile=IsMobile=NO; _ga_D40MBMET7Z=GS1.1.1661141800.2.1.1661141969.0.0.0; _ga_860L8F5EZP=GS1.1.1661141792.3.1.1661141970.0.0.0; _ga=GA1.2.480233724.1658202174; _gat_gtag_UA_34575478_17=1; __uif=__uid%3A1375247731963110594%7C__create%3A1657524773',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
            }

    playload = {
            'ctl00$ContentPlaceHolder1$ctl03$txtKeyword': Name,
            '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ctl03$pager2',
            '__EVENTARGUMENT': Page,
            }

    url = 'https://s.cafef.vn/Lich-su-giao-dich-'+Name+'-1.chn'
    crawl = requests.post(url, headers = header, data = playload)
    return crawl.text

def count_page(Name):
    count_page = 1
    while True:

        check = claw_DataStock_Gcafe(Name, count_page)
        if check.find('style="font-family: Arial; font-size: 10px; font-weight: normal; background-color: #FFF;height:30px;padding-right:5px">') == -1:
            return count_page
            break

        count_page += 1

data = []
name = 'NDN'
for i in range(count_page(name)):
    fill_data = claw_DataStock_Gcafe(name, i)
    fill_data = fill_data.split('<tr')
    for data_index in range(len(fill_data)):
        if fill_data[data_index].find('<td class="Item_DateItem">') != -1:
            date  = fill_data[data_index].split('<td')[1][fill_data[data_index].split('<td')[1].find('>')+1:fill_data[data_index].split('<td')[1].find('<')].replace(',','')
            price = fill_data[data_index].split('<td')[2][fill_data[data_index].split('<td')[2].find('>')+1:fill_data[data_index].split('<td')[2].find('&')].replace(',','')
            vol   = fill_data[data_index].split('<td')[6][fill_data[data_index].split('<td')[6].find('>')+1:fill_data[data_index].split('<td')[6].find('&')].replace(',','')
            if float(price) != 0 and int(vol) != 0:
                data.append((date, float(price), int(vol)))

# %%
volPriceStock_df = pd.DataFrame(data, columns =['Date', 'Price', 'Volume'])

volPriceStock_df = volPriceStock_df[::-1].reset_index()
volPriceStock_df = volPriceStock_df.drop(['index'], axis=1)
volPriceStock_df
# Out:
#             Date  Price  Volume
# 0     21/04/2011   1.88  492500
# 1     22/04/2011   1.79   65800
# 2     25/04/2011   1.76   53000
# 3     26/04/2011   1.71   69000
# 4     27/04/2011   1.69  215900
# ...          ...    ...     ...
# 2839  05/09/2022  10.50  228404
# 2840  06/09/2022  10.60  556720
# 2841  07/09/2022  10.40  228380
# 2842  08/09/2022  10.30  299534
# 2843  09/09/2022  10.40  275539
#
# [2844 rows x 3 columns]

# %%
Price = volPriceStock_df['Price'].to_numpy()


plt.plot(Price)

# %%
volume = volPriceStock_df['Volume'].to_numpy()

plt.plot(volume)

# %%
print('Volume_shape: ', volume.shape)
print('Price_shape: ', Price.shape)
# Out:
# Volume_shape:  (2844,)
# Price_shape:  (2844,)

# %%
X_price = []
X_Volume = []
Y = []
step = 10
range_pred = 3
for i in range(0, len(Price)-step, step):
    X_price.append(Price[i:i+step-range_pred])
    X_Volume.append(volume[i:i+step-range_pred])
    Y.append(Price[i+step-range_pred:i+step])

# %%
X_price, X_Volume, Y = np.array(X_price), np.array(X_Volume), np.array(Y)

print('X_price shape =',X_price.shape)
print('X_Volume shape =',X_Volume.shape)
print('y shape =',Y.shape)
# Out:
# X_price shape = (284, 7)
# X_Volume shape = (284, 7)
# y shape = (284, 3)

# %%
# create df for price
mean_price_df = pd.DataFrame(X_price, columns =['price_1', 'price_2', 'price_3', 'price_4', 'price_5', 'price_6', 'price_7'])
mean_price_df
# Out:
#      price_1  price_2  price_3  price_4  price_5  price_6  price_7
# 0       1.88     1.79     1.76     1.71     1.69     1.78     1.83
# 1       1.73     1.73     1.71     1.79     1.89     1.92     1.84
# 2       1.79     1.73     1.68     1.66     1.64     1.55     1.55
# 3       1.61     1.63     1.63     1.64     1.71     1.71     1.63
# 4       1.51     1.53     1.43     1.35     1.45     1.48     1.43
# ..       ...      ...      ...      ...      ...      ...      ...
# 279    10.70    10.90    11.30    10.90    10.60    10.80    10.80
# 280    10.70    10.70    11.00    11.10    11.10    11.50    11.50
# 281    10.70    10.60    10.40    10.50    10.60    10.50    10.70
# 282    11.20    11.30    11.20    11.30    12.00    12.00    11.80
# 283    11.20    10.80    10.80    10.70    10.70    10.80    10.50
#
# [284 rows x 7 columns]

# %%
# create df for vol
mean_vol_df = pd.DataFrame(X_Volume, columns =['vol_1', 'vol_2', 'vol_3', 'vol_4', 'vol_5', 'vol_6', 'vol_7'])
mean_vol_df
# Out:
#        vol_1   vol_2   vol_3    vol_4    vol_5   vol_6   vol_7
# 0     492500   65800   53000    69000   215900  214800   79100
# 1      47100   37700   76500   215300   291400  147000  141600
# 2     147800   69300   57000   209400   110000   26700   92300
# 3      44000   80600   44400    51800    48500   46600   74000
# 4      50300   20300   68100    87200    50100   45200   18000
# ..       ...     ...     ...      ...      ...     ...     ...
# 279  1625400  387609  817021  1004261   546350  483520  391920
# 280   366660  342933  488116   340800   231673  466511  475168
# 281  1245900  433445  362100   259615   351020  234871  256133
# 282   302160  471932  446200   582794  1665935  385986  786060
# 283   396681  737617  489469   350110   366965  665182  645140
#
# [284 rows x 7 columns]

# %%
# Calculate the mean of each column
means_price = [mean_price_df[col].mean() for col in mean_price_df]
means_vol   = [mean_vol_df[col].mean() for col in mean_vol_df]
# means
print('means_price = ', means_price)
print('means_vol   = ', means_vol)
# Out:
# means_price =  [6.156690140845072, 6.147042253521127, 6.14661971830986, 6.154049295774649, 6.150457746478872, 6.165176056338028, 6.148556338028173]
# means_vol   =  [493269.6478873239, 481903.5985915493, 446669.17957746476, 486677.16549295775, 464475.3098591549, 450262.4859154929, 464708.3133802817]

# %%
# Calculate the Std. Deviation of each column
std_price = [mean_price_df[col].std() for col in mean_price_df]
std_vol   = [mean_vol_df[col].std() for col in mean_vol_df]
# means
print('std_price = ', std_price)
print('std_vol   = ', std_vol)
# Out:
# std_price =  [5.141975768240699, 5.129211400925239, 5.118503174991819, 5.105476116105103, 5.096389299167372, 5.110108838017621, 5.078195788543356]
# std_vol   =  [991468.7126432103, 702300.2673063016, 765974.217872387, 836018.5635528087, 721579.6918948423, 595839.0076517514, 750347.823636472]

# %%
# Create TensorFlow preprocessing function for stats stream
def stat_scaler_price(tensor):
    return (tensor - means_price) / std_price

def stat_scaler_vol(tensor):
    return (tensor - means_vol) / std_vol

# %%
split = int(len(X_price)*95/100)
x_train_price, x_test_price = X_price[:split], X_price[split:]
x_train_vol, x_test_vol = X_Volume[:split], X_Volume[split:]

y_train, y_test = Y[:split], Y[split:]

print('x_train_price shape =',x_train_price.shape)
print('x_test_price shape =',x_test_price.shape)
print('x_train_vol shape =',x_train_vol.shape)
print('x_test_vol shape =',x_test_vol.shape)
print('y_train shape =',y_train.shape)
print('y_test shape =',y_test.shape)
# Out:
# x_train_price shape = (269, 7)
# x_test_price shape = (15, 7)
# x_train_vol shape = (269, 7)
# x_test_vol shape = (15, 7)
# y_train shape = (269, 3)
# y_test shape = (15, 3)

# %%
def build_model():
    # Inputs to the model
    input_Price = layers.Input(shape=(7,))
    x           = layers.Lambda(stat_scaler_price)(input_Price)
    x           = layers.Dense(64, activation="relu")(x)
    x           = layers.Dropout(0.2)(x)
    x           = layers.Dense(128, activation="relu")(x)
    x           = layers.Dropout(0.2)(x)
    x           = layers.Dense(256, activation="relu")(x)
    x           = layers.Dropout(0.2)(x)
    x           = layers.Dense(512, activation="relu")(x)
    x           = layers.Dropout(0.2)(x)
    x           = layers.Dense(512, activation="relu")(x)
    x           = layers.Dropout(0.2)(x)
    x           = layers.Dense(3, activation="linear")(x)
    
    # Define the final model
    model = Model(inputs=input_Price, outputs=x, name="Predict_Stock")
    
    # Compile the model with Adam optimizer and mean-squared-error loss function
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    
    model.compile(optimizer=optimizer,loss='mse')
    
    return model

# %%
# import tensorflow as tf

# # xây dựng mô hình
# def create_model():
#     # định nghĩa thuật toán tối ưu
#     optimizer = tf.keras.optimizers.SGD(learning_rate=0.002)
    
#     model = tf.keras.models.Sequential()
    
#     model.add(tf.keras.Input(shape=(7,)))
#     model.add(tf.keras.layers.Lambda(stat_scaler_price))
#     model.add(tf.keras.layers.Dense(64, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(128, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(256, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(512, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(512, activation='relu'))
#     model.add(tf.keras.layers.Dropout(0.2))
#     model.add(tf.keras.layers.Dense(3, activation = 'softmax'))
    
#     model.compile(optimizer=optimizer,
#                   loss='mse')

#     return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "Predict_Stock"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 7)]               0
#
#  lambda_8 (Lambda)           (None, 7)                 0
#
#  dense_36 (Dense)            (None, 64)                512
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_37 (Dense)            (None, 128)               8320
#
#  dropout_30 (Dropout)        (None, 128)               0
#
#  dense_38 (Dense)            (None, 256)               33024
#
#  dropout_31 (Dropout)        (None, 256)               0
#
#  dense_39 (Dense)            (None, 512)               131584
#
#  dropout_32 (Dropout)        (None, 512)               0
#
#  dense_40 (Dense)            (None, 512)               262656
#
#  dropout_33 (Dropout)        (None, 512)               0
#
#  dense_41 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 437,635
# Trainable params: 437,635
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Thiết lập hàm call back Early Stopping
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.1, mode="auto", patience=150, restore_best_weights=True)


history = model.fit(x_train_price, y_train, epochs = 5000, batch_size = 100, validation_split=0.25, shuffle=True, callbacks = callback)
# Out:
# Epoch 1/5000
# 3/3 [==============================] - 1s 116ms/step - loss: 14.2693 - val_loss: 172.1514
# Epoch 2/5000
# 3/3 [==============================] - 0s 41ms/step - loss: 12.9901 - val_loss: 163.4794
# Epoch 3/5000
# 3/3 [==============================] - 0s 41ms/step - loss: 11.4189 - val_loss: 152.8586
# Epoch 4/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 9.6632 - val_loss: 138.4888
# Epoch 5/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 7.8965 - val_loss: 125.0449
# Epoch 6/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 7.0402 - val_loss: 126.2896
# Epoch 7/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 6.7620 - val_loss: 105.8406
# Epoch 8/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 6.4451 - val_loss: 113.2578
# Epoch 9/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 5.8340 - val_loss: 116.4881
# Epoch 10/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 6.0009 - val_loss: 115.2767
# Epoch 11/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 5.8727 - val_loss: 96.3689
# Epoch 12/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 5.1385 - val_loss: 82.6925
# Epoch 13/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 4.8594 - val_loss: 101.5626
# Epoch 14/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 4.9496 - val_loss: 80.3285
# Epoch 15/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 4.1735 - val_loss: 60.5806
# Epoch 16/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 4.0992 - val_loss: 52.5427
# Epoch 17/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 3.7135 - val_loss: 50.7769
# Epoch 18/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 3.3025 - val_loss: 60.6065
# Epoch 19/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.0626 - val_loss: 2.3499
# Epoch 20/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 3.5688 - val_loss: 6.6103
# Epoch 21/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.7359 - val_loss: 2.9001
# Epoch 22/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4397 - val_loss: 1.0646
# Epoch 23/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3175 - val_loss: 3.4232
# Epoch 24/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.6229 - val_loss: 3.2119
# Epoch 25/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2538 - val_loss: 2.2170
# Epoch 26/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.9811 - val_loss: 0.9035
# Epoch 27/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.9419 - val_loss: 0.9757
# Epoch 28/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.8232 - val_loss: 4.2096
# Epoch 29/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.2799 - val_loss: 2.2608
# Epoch 30/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9881 - val_loss: 2.2280
# Epoch 31/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7871 - val_loss: 2.7964
# Epoch 32/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.6260 - val_loss: 1.1644
# Epoch 33/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5313 - val_loss: 1.3891
# Epoch 34/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.5423 - val_loss: 1.4892
# Epoch 35/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.6723 - val_loss: 2.3317
# Epoch 36/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7456 - val_loss: 10.6722
# Epoch 37/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.1395 - val_loss: 3.3628
# Epoch 38/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6666 - val_loss: 2.1045
# Epoch 39/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3984 - val_loss: 1.9913
# Epoch 40/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.4346 - val_loss: 1.0777
# Epoch 41/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.4719 - val_loss: 7.3651
# Epoch 42/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5162 - val_loss: 1.5927
# Epoch 43/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5449 - val_loss: 3.0458
# Epoch 44/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3922 - val_loss: 1.9230
# Epoch 45/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2957 - val_loss: 12.1077
# Epoch 46/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3945 - val_loss: 3.0035
# Epoch 47/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4769 - val_loss: 1.2924
# Epoch 48/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.5295 - val_loss: 1.6485
# Epoch 49/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3813 - val_loss: 3.9476
# Epoch 50/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8373 - val_loss: 1.3605
# Epoch 51/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6569 - val_loss: 53.7571
# Epoch 52/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6957 - val_loss: 9.2583
# Epoch 53/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4112 - val_loss: 2.5555
# Epoch 54/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3993 - val_loss: 1.9728
# Epoch 55/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3829 - val_loss: 1.4800
# Epoch 56/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4701 - val_loss: 4.6800
# Epoch 57/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3614 - val_loss: 3.4946
# Epoch 58/5000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4135 - val_loss: 2.1844
# Epoch 59/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.5362 - val_loss: 0.6541
# Epoch 60/5000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4719 - val_loss: 1.1730
# Epoch 61/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3026 - val_loss: 0.8514
# Epoch 62/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2964 - val_loss: 0.9390
# Epoch 63/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.3772 - val_loss: 1.1096
# Epoch 64/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2840 - val_loss: 2.3104
# Epoch 65/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3395 - val_loss: 1.1408
# Epoch 66/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3261 - val_loss: 3.6324
# Epoch 67/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.5413 - val_loss: 0.9952
# Epoch 68/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3168 - val_loss: 0.5662
# Epoch 69/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2567 - val_loss: 0.5958
# Epoch 70/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3107 - val_loss: 0.7392
# Epoch 71/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2512 - val_loss: 0.5950
# Epoch 72/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2936 - val_loss: 0.9939
# Epoch 73/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3169 - val_loss: 0.7201
# Epoch 74/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.3808 - val_loss: 1.9447
# Epoch 75/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3700 - val_loss: 0.8308
# Epoch 76/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2889 - val_loss: 0.6045
# Epoch 77/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3789 - val_loss: 0.5873
# Epoch 78/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4233 - val_loss: 0.8077
# Epoch 79/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.5416 - val_loss: 2.6103
# Epoch 80/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2786 - val_loss: 1.2736
# Epoch 81/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2948 - val_loss: 2.0439
# Epoch 82/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2652 - val_loss: 1.2068
# Epoch 83/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3190 - val_loss: 2.8464
# Epoch 84/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3689 - val_loss: 0.9469
# Epoch 85/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2155 - val_loss: 1.7795
# Epoch 86/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7247 - val_loss: 0.7591
# Epoch 87/5000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3903 - val_loss: 0.5848
# Epoch 88/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2714 - val_loss: 2.1277
# Epoch 89/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3260 - val_loss: 1.8565
# Epoch 90/5000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6650 - val_loss: 0.6252
# Epoch 91/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2794 - val_loss: 0.7845
# Epoch 92/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2447 - val_loss: 0.7517
# Epoch 93/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3070 - val_loss: 1.0806
# Epoch 94/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4478 - val_loss: 0.6261
# Epoch 95/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2929 - val_loss: 0.7495
# Epoch 96/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.5471 - val_loss: 0.5442
# Epoch 97/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3638 - val_loss: 0.5928
# Epoch 98/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3052 - val_loss: 0.5792
# Epoch 99/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2964 - val_loss: 0.6520
# Epoch 100/5000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3211 - val_loss: 0.6148
# Epoch 101/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2739 - val_loss: 1.1716
# Epoch 102/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.4262 - val_loss: 0.6672
# Epoch 103/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2816 - val_loss: 0.8022
# Epoch 104/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2840 - val_loss: 0.7231
# Epoch 105/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3174 - val_loss: 1.4890
# Epoch 106/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.4113 - val_loss: 0.8881
# Epoch 107/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3261 - val_loss: 1.0939
# Epoch 108/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2987 - val_loss: 0.7546
# Epoch 109/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2823 - val_loss: 0.6493
# Epoch 110/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2974 - val_loss: 0.8590
# Epoch 111/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2856 - val_loss: 14.1392
# Epoch 112/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7969 - val_loss: 4.1898
# Epoch 113/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3416 - val_loss: 1.6423
# Epoch 114/5000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.3661 - val_loss: 1.2590
# Epoch 115/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3330 - val_loss: 0.5575
# Epoch 116/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2190 - val_loss: 17.7211
# Epoch 117/5000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.8159 - val_loss: 9.5032
# Epoch 118/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9576 - val_loss: 1.8695
# Epoch 119/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2937 - val_loss: 48.6735
# Epoch 120/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 2.2937 - val_loss: 20.0641
# Epoch 121/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6076 - val_loss: 12.7523
# Epoch 122/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4983 - val_loss: 2.6094
# Epoch 123/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3837 - val_loss: 3.1062
# Epoch 124/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3097 - val_loss: 1.7965
# Epoch 125/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2864 - val_loss: 1.5127
# Epoch 126/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.2566 - val_loss: 1.1319
# Epoch 127/5000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4234 - val_loss: 2.4675
# Epoch 128/5000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2425 - val_loss: 1.2298
# Epoch 129/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3150 - val_loss: 1.6899
# Epoch 130/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2531 - val_loss: 1.3694
# Epoch 131/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2695 - val_loss: 0.8180
# Epoch 132/5000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2605 - val_loss: 0.5182
# Epoch 133/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3125 - val_loss: 18.5720
# Epoch 134/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6490 - val_loss: 8.8414
# Epoch 135/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.3378 - val_loss: 6.1890
# Epoch 136/5000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3708 - val_loss: 3.2830
# Epoch 137/5000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2510 - val_loss: 5.0687
# Epoch 138/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3846 - val_loss: 0.6580
# Epoch 139/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3283 - val_loss: 0.4596
# Epoch 140/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4714 - val_loss: 1.1213
# Epoch 141/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2780 - val_loss: 5.2986
# Epoch 142/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.5890 - val_loss: 0.5906
# Epoch 143/5000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.3008 - val_loss: 0.4434
# Epoch 144/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2884 - val_loss: 0.6562
# Epoch 145/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2969 - val_loss: 1.0825
# Epoch 146/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3115 - val_loss: 0.7604
# Epoch 147/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2838 - val_loss: 0.4631
# Epoch 148/5000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2366 - val_loss: 0.9041
# Epoch 149/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2356 - val_loss: 0.9046
# Epoch 150/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2449 - val_loss: 0.8338
# Epoch 151/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2734 - val_loss: 0.4478
# Epoch 152/5000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3565 - val_loss: 6.8515
# Epoch 153/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6344 - val_loss: 2.5215
# Epoch 154/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3677 - val_loss: 0.7318
# Epoch 155/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2808 - val_loss: 0.5111
# Epoch 156/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2952 - val_loss: 0.5163
# Epoch 157/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2636 - val_loss: 0.4858
# Epoch 158/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2770 - val_loss: 0.6043
# Epoch 159/5000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2820 - val_loss: 0.4691
# Epoch 160/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1997 - val_loss: 0.6533
# Epoch 161/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3705 - val_loss: 1.7678
# Epoch 162/5000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.2782 - val_loss: 1.1160
# Epoch 163/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.5517 - val_loss: 26.4394
# Epoch 164/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1398 - val_loss: 3.6987
# Epoch 165/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6990 - val_loss: 0.5644
# Epoch 166/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4318 - val_loss: 1.6672
# Epoch 167/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2717 - val_loss: 1.2901
# Epoch 168/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2675 - val_loss: 0.7212
# Epoch 169/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2191 - val_loss: 0.5604
# Epoch 170/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2153 - val_loss: 0.4882
# Epoch 171/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2039 - val_loss: 0.4840
# Epoch 172/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2835 - val_loss: 0.6515
# Epoch 173/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2404 - val_loss: 0.5485
# Epoch 174/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2838 - val_loss: 0.6496
# Epoch 175/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2587 - val_loss: 0.4965
# Epoch 176/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2300 - val_loss: 0.5532
# Epoch 177/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3461 - val_loss: 3.1032
# Epoch 178/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4909 - val_loss: 0.6918
# Epoch 179/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2941 - val_loss: 0.5561
# Epoch 180/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2698 - val_loss: 0.4881
# Epoch 181/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2435 - val_loss: 18.2506
# Epoch 182/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6129 - val_loss: 2.3435
# Epoch 183/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2126 - val_loss: 3.2938
# Epoch 184/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.6271 - val_loss: 0.6729
# Epoch 185/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.1938 - val_loss: 7.1124
# Epoch 186/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.5908 - val_loss: 0.7532
# Epoch 187/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2349 - val_loss: 0.7866
# Epoch 188/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3084 - val_loss: 12.2986
# Epoch 189/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.7159 - val_loss: 3.9819
# Epoch 190/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3218 - val_loss: 0.7470
# Epoch 191/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2210 - val_loss: 22.3227
# Epoch 192/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.6267 - val_loss: 7.4485
# Epoch 193/5000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.5451 - val_loss: 1.3823
# Epoch 194/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2512 - val_loss: 2.0638
# Epoch 195/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2532 - val_loss: 1.0684
# Epoch 196/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3214 - val_loss: 0.7410
# Epoch 197/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2180 - val_loss: 3.1524
# Epoch 198/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3466 - val_loss: 0.6347
# Epoch 199/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3359 - val_loss: 1.0766
# Epoch 200/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2582 - val_loss: 1.0671
# Epoch 201/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3052 - val_loss: 0.5931
# Epoch 202/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2915 - val_loss: 0.7209
# Epoch 203/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.5125 - val_loss: 1.6916
# Epoch 204/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2734 - val_loss: 21.4164
# Epoch 205/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.1601 - val_loss: 6.8436
# Epoch 206/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3883 - val_loss: 2.3674
# Epoch 207/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2826 - val_loss: 1.3476
# Epoch 208/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2576 - val_loss: 1.0212
# Epoch 209/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2618 - val_loss: 0.4949
# Epoch 210/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3863 - val_loss: 1.7381
# Epoch 211/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2569 - val_loss: 0.6844
# Epoch 212/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2510 - val_loss: 0.4921
# Epoch 213/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2519 - val_loss: 0.6952
# Epoch 214/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3205 - val_loss: 1.1927
# Epoch 215/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2695 - val_loss: 9.9413
# Epoch 216/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4613 - val_loss: 0.7962
# Epoch 217/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2608 - val_loss: 0.8089
# Epoch 218/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2244 - val_loss: 0.8393
# Epoch 219/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1929 - val_loss: 0.5896
# Epoch 220/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2337 - val_loss: 0.8129
# Epoch 221/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1553 - val_loss: 0.7067
# Epoch 222/5000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2349 - val_loss: 45.9869
# Epoch 223/5000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3080 - val_loss: 6.2455
# Epoch 224/5000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2670 - val_loss: 1.6402
# Epoch 225/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3334 - val_loss: 1.0020
# Epoch 226/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2698 - val_loss: 1.3839
# Epoch 227/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1995 - val_loss: 2.1350
# Epoch 228/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2617 - val_loss: 1.4550
# Epoch 229/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2368 - val_loss: 1.8072
# Epoch 230/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2244 - val_loss: 1.3045
# Epoch 231/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2175 - val_loss: 0.6464
# Epoch 232/5000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2266 - val_loss: 3.1687
# Epoch 233/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3005 - val_loss: 2.7806
# Epoch 234/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.2338 - val_loss: 1.8459
# Epoch 235/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3269 - val_loss: 0.5063
# Epoch 236/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2331 - val_loss: 0.6496
# Epoch 237/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3050 - val_loss: 14.5137
# Epoch 238/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3563 - val_loss: 5.3011
# Epoch 239/5000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2732 - val_loss: 60.7605
# Epoch 240/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3448 - val_loss: 6.9118
# Epoch 241/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3017 - val_loss: 3.2597
# Epoch 242/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2393 - val_loss: 6.0218
# Epoch 243/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3231 - val_loss: 2.0248
# Epoch 244/5000
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2073 - val_loss: 0.9350
# Epoch 245/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2498 - val_loss: 1.2754
# Epoch 246/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1930 - val_loss: 1.4341
# Epoch 247/5000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2630 - val_loss: 0.7411
# Epoch 248/5000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.2075 - val_loss: 0.5770
# Epoch 249/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1950 - val_loss: 0.6483
# Epoch 250/5000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2427 - val_loss: 0.4917
# Epoch 251/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1973 - val_loss: 1.5138
# Epoch 252/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2301 - val_loss: 1.1928
# Epoch 253/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3094 - val_loss: 0.8004
# Epoch 254/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2743 - val_loss: 0.5159
# Epoch 255/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2264 - val_loss: 1.8142
# Epoch 256/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2352 - val_loss: 10.1471
# Epoch 257/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4383 - val_loss: 15.4875
# Epoch 258/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4627 - val_loss: 4.2337
# Epoch 259/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2892 - val_loss: 2.6431
# Epoch 260/5000
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2745 - val_loss: 90.1140
# Epoch 261/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 1.8944 - val_loss: 15.5806
# Epoch 262/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.4241 - val_loss: 5.6961
# Epoch 263/5000
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2574 - val_loss: 4.2483
# Epoch 264/5000
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2093 - val_loss: 2.4087
# Epoch 265/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2494 - val_loss: 3.9314
# Epoch 266/5000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.5755 - val_loss: 0.7658
# Epoch 267/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2066 - val_loss: 0.9377
# Epoch 268/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2331 - val_loss: 2.3224
# Epoch 269/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2829 - val_loss: 1.0460
# Epoch 270/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2047 - val_loss: 1.3938
# Epoch 271/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1717 - val_loss: 1.0540
# Epoch 272/5000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2194 - val_loss: 0.8881
# Epoch 273/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2252 - val_loss: 0.8598
# Epoch 274/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1543 - val_loss: 0.8648
# Epoch 275/5000
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2739 - val_loss: 0.8139
# Epoch 276/5000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2951 - val_loss: 0.5561
# Epoch 277/5000
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2652 - val_loss: 0.6055
# Epoch 278/5000
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3414 - val_loss: 1.2456
# Epoch 279/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2666 - val_loss: 2.3541
# Epoch 280/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3009 - val_loss: 0.4823
# Epoch 281/5000
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3180 - val_loss: 0.4944
# Epoch 282/5000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2996 - val_loss: 0.5603
# Epoch 283/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2373 - val_loss: 0.5227
# Epoch 284/5000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2134 - val_loss: 5.4729
# Epoch 285/5000
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3430 - val_loss: 2.3652
# Epoch 286/5000
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2307 - val_loss: 2.1839
# Epoch 287/5000
# 3/3 [==============================] - 0s 44ms/step - loss: 0.2555 - val_loss: 1.1797
# Epoch 288/5000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2521 - val_loss: 0.6812
# Epoch 289/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1802 - val_loss: 1.2126
# Epoch 290/5000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2107 - val_loss: 7.1092
# Epoch 291/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3725 - val_loss: 0.5098
# Epoch 292/5000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1918 - val_loss: 0.5604
# Epoch 293/5000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1871 - val_loss: 0.5018

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %%
test_predictions =  model.predict(x_test_price)

for i in range(9):
    print(f'giá dự đoán: {test_predictions[i]}  Giá thực tế {y_test[i]}')
    
count = 0
for i in range(len(test_predictions)):
    check = round(float(test_predictions[i][0]), 2) - float(y_test[i][0])
    if -0.2 < check < 0.2:
        count += 1

print(f'Xác suất dự đoán trúng = {count/len(test_predictions)*100}')
# Out:
# 1/1 [==============================] - 0s 118ms/step
# giá dự đoán: [13.59762  13.758648 13.945689]  Giá thực tế [14.05 14.5  14.41]
# giá dự đoán: [15.618507 15.810322 16.02099 ]  Giá thực tế [17.2  17.02 16.39]
# giá dự đoán: [17.529514 17.763113 18.001553]  Giá thực tế [18.01 18.01 17.92]
# giá dự đoán: [16.583548 16.808954 17.03423 ]  Giá thực tế [17.2 17.  16.9]
# giá dự đoán: [16.005209 16.223488 16.435566]  Giá thực tế [16.2 16.2 16. ]
# giá dự đoán: [13.763317 13.929223 14.121472]  Giá thực tế [13.1 11.9 12.7]
# giá dự đoán: [14.034846 14.206348 14.398063]  Giá thực tế [14.  14.  13.6]
# giá dự đoán: [13.428963 13.581939 13.763926]  Giá thực tế [13.5 13.9 13.9]
# giá dự đoán: [13.300951 13.459989 13.640309]  Giá thực tế [13.  13.3 13.3]
# Xác suất dự đoán trúng = 40.0

# %%
# save model
model.save(r'C:\Users\HP\Desktop\newthing AI\PredictStock_DeepLearning\Save_model\PredictStock_NDN.h5')

# %%
#ndn rate 40%
from tensorflow.keras.models import load_model
Stock_Symbol = 'NDN'
model = load_model(fr'C:\Users\HP\Desktop\newthing AI\PredictStock_DeepLearning\Save_model\PredictStock_{Stock_Symbol}.h5')

x = Price[-7:]
price_7days = tf.expand_dims(x,0)
price_pred =  model.predict(price_7days)
price_pred
# Out:
# 1/1 [==============================] - 0s 134ms/step
# array([[10.381558, 10.469174, 10.61329 ]], dtype=float32)
